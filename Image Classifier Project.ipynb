# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import pandas as pd
import numpy as np
from torch import nn
from torch import optim
import torch.nn.functional as F

from torchvision import datasets, transforms, models
import torch
from collections import OrderedDict
from PIL import Image

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

train_transforms = transforms.Compose([transforms.RandomResizedCrop(250),
                                       transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.RandomVerticalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(250),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

valid_transforms = transforms.Compose([transforms.Resize(250),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
test_data = datasets.ImageFolder(test_dir, transform=test_transforms)
valid_data = datasets.ImageFolder(valid_dir, transform=test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network

# Pre-trained network:

model = models.vgg13(pretrained=True)
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg13-c768596a.pth" to /root/.torch/models/vgg13-c768596a.pth
# 100%|██████████| 532194478/532194478 [00:05<00:00, 98715872.79it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU(inplace)
#     (17): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (20): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU(inplace)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU(inplace)
#     (24): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Freeze parameters

for param in model.parameters():
    param.requires_grad = False


classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(25088, 3500)),
                          ('dropout', nn.Dropout(0.5)),
                          ('relu', nn.ReLU()),
                          ('fc2', nn.Linear(3500, 102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
    
model.classifier = classifier

criterion = nn.NLLLoss() 

optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device);

# %%
epochs = 10
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
    for inputs, labels in trainloader:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        if steps % print_every == 0:
            valid_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in validloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    valid_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor))
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Validation loss: {valid_loss/len(validloader):.3f}.. "
                  f"Validation accuracy: {accuracy/len(validloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# Epoch 1/10.. Train loss: 9.957.. Validation loss: 9.630.. Validation accuracy: 0.068
# Epoch 1/10.. Train loss: 9.415.. Validation loss: 7.989.. Validation accuracy: 0.046
# Epoch 1/10.. Train loss: 6.316.. Validation loss: 4.906.. Validation accuracy: 0.140
# Epoch 1/10.. Train loss: 4.792.. Validation loss: 3.845.. Validation accuracy: 0.205
# Epoch 1/10.. Train loss: 4.041.. Validation loss: 3.309.. Validation accuracy: 0.259
# Epoch 1/10.. Train loss: 3.622.. Validation loss: 3.149.. Validation accuracy: 0.271
# Epoch 1/10.. Train loss: 3.471.. Validation loss: 3.024.. Validation accuracy: 0.315
# Epoch 1/10.. Train loss: 3.603.. Validation loss: 2.774.. Validation accuracy: 0.370
# Epoch 1/10.. Train loss: 3.275.. Validation loss: 2.570.. Validation accuracy: 0.396
# Epoch 1/10.. Train loss: 3.146.. Validation loss: 2.448.. Validation accuracy: 0.410
# Epoch 1/10.. Train loss: 3.052.. Validation loss: 2.347.. Validation accuracy: 0.400
# Epoch 1/10.. Train loss: 2.940.. Validation loss: 2.310.. Validation accuracy: 0.411
# Epoch 1/10.. Train loss: 2.817.. Validation loss: 2.044.. Validation accuracy: 0.488
# Epoch 1/10.. Train loss: 2.905.. Validation loss: 1.947.. Validation accuracy: 0.494
# Epoch 1/10.. Train loss: 2.824.. Validation loss: 1.889.. Validation accuracy: 0.515
# Epoch 1/10.. Train loss: 2.716.. Validation loss: 1.894.. Validation accuracy: 0.499
# Epoch 1/10.. Train loss: 2.753.. Validation loss: 1.799.. Validation accuracy: 0.529
# Epoch 1/10.. Train loss: 2.493.. Validation loss: 1.661.. Validation accuracy: 0.565
# Epoch 1/10.. Train loss: 2.598.. Validation loss: 1.593.. Validation accuracy: 0.577
# Epoch 1/10.. Train loss: 2.767.. Validation loss: 1.612.. Validation accuracy: 0.563
# Epoch 2/10.. Train loss: 2.394.. Validation loss: 1.571.. Validation accuracy: 0.583
# Epoch 2/10.. Train loss: 2.272.. Validation loss: 1.590.. Validation accuracy: 0.576
# Epoch 2/10.. Train loss: 2.523.. Validation loss: 1.479.. Validation accuracy: 0.601
# Epoch 2/10.. Train loss: 2.469.. Validation loss: 1.442.. Validation accuracy: 0.602
# Epoch 2/10.. Train loss: 2.454.. Validation loss: 1.385.. Validation accuracy: 0.611
# Epoch 2/10.. Train loss: 2.338.. Validation loss: 1.343.. Validation accuracy: 0.630
# Epoch 2/10.. Train loss: 2.339.. Validation loss: 1.316.. Validation accuracy: 0.635
# Epoch 2/10.. Train loss: 2.203.. Validation loss: 1.288.. Validation accuracy: 0.646
# Epoch 2/10.. Train loss: 2.391.. Validation loss: 1.272.. Validation accuracy: 0.646
# Epoch 2/10.. Train loss: 2.378.. Validation loss: 1.319.. Validation accuracy: 0.663
# Epoch 2/10.. Train loss: 2.309.. Validation loss: 1.343.. Validation accuracy: 0.630
# Epoch 2/10.. Train loss: 2.435.. Validation loss: 1.377.. Validation accuracy: 0.628
# Epoch 2/10.. Train loss: 2.579.. Validation loss: 1.285.. Validation accuracy: 0.646
# Epoch 2/10.. Train loss: 2.224.. Validation loss: 1.236.. Validation accuracy: 0.657
# Epoch 2/10.. Train loss: 2.283.. Validation loss: 1.256.. Validation accuracy: 0.654
# Epoch 2/10.. Train loss: 2.269.. Validation loss: 1.211.. Validation accuracy: 0.660
# Epoch 2/10.. Train loss: 2.410.. Validation loss: 1.110.. Validation accuracy: 0.691
# Epoch 2/10.. Train loss: 2.195.. Validation loss: 1.204.. Validation accuracy: 0.672
# Epoch 2/10.. Train loss: 2.138.. Validation loss: 1.251.. Validation accuracy: 0.670
# Epoch 2/10.. Train loss: 2.181.. Validation loss: 1.280.. Validation accuracy: 0.669
# Epoch 2/10.. Train loss: 2.194.. Validation loss: 1.165.. Validation accuracy: 0.695
# Epoch 3/10.. Train loss: 2.124.. Validation loss: 1.299.. Validation accuracy: 0.658
# Epoch 3/10.. Train loss: 2.248.. Validation loss: 1.159.. Validation accuracy: 0.664
# Epoch 3/10.. Train loss: 2.019.. Validation loss: 1.211.. Validation accuracy: 0.652
# Epoch 3/10.. Train loss: 2.214.. Validation loss: 1.248.. Validation accuracy: 0.657
# Epoch 3/10.. Train loss: 2.241.. Validation loss: 1.239.. Validation accuracy: 0.644
# Epoch 3/10.. Train loss: 1.976.. Validation loss: 1.110.. Validation accuracy: 0.688
# Epoch 3/10.. Train loss: 2.183.. Validation loss: 1.137.. Validation accuracy: 0.691
# Epoch 3/10.. Train loss: 1.980.. Validation loss: 1.108.. Validation accuracy: 0.700
# Epoch 3/10.. Train loss: 2.064.. Validation loss: 1.142.. Validation accuracy: 0.678
# Epoch 3/10.. Train loss: 2.089.. Validation loss: 1.170.. Validation accuracy: 0.663
# Epoch 3/10.. Train loss: 2.069.. Validation loss: 1.082.. Validation accuracy: 0.696
# Epoch 3/10.. Train loss: 2.079.. Validation loss: 1.057.. Validation accuracy: 0.703
# Epoch 3/10.. Train loss: 1.976.. Validation loss: 1.084.. Validation accuracy: 0.699
# Epoch 3/10.. Train loss: 1.990.. Validation loss: 1.060.. Validation accuracy: 0.699
# Epoch 3/10.. Train loss: 2.103.. Validation loss: 1.017.. Validation accuracy: 0.707
# Epoch 3/10.. Train loss: 1.925.. Validation loss: 1.050.. Validation accuracy: 0.710
# Epoch 3/10.. Train loss: 2.053.. Validation loss: 1.051.. Validation accuracy: 0.718
# Epoch 3/10.. Train loss: 2.274.. Validation loss: 1.033.. Validation accuracy: 0.715
# Epoch 3/10.. Train loss: 2.078.. Validation loss: 0.938.. Validation accuracy: 0.736
# Epoch 3/10.. Train loss: 1.875.. Validation loss: 0.995.. Validation accuracy: 0.725
# Epoch 4/10.. Train loss: 2.033.. Validation loss: 0.956.. Validation accuracy: 0.727
# Epoch 4/10.. Train loss: 1.962.. Validation loss: 0.942.. Validation accuracy: 0.724
# Epoch 4/10.. Train loss: 2.033.. Validation loss: 0.974.. Validation accuracy: 0.715
# Epoch 4/10.. Train loss: 1.988.. Validation loss: 0.999.. Validation accuracy: 0.718
# Epoch 4/10.. Train loss: 2.042.. Validation loss: 0.954.. Validation accuracy: 0.722
# Epoch 4/10.. Train loss: 1.964.. Validation loss: 0.899.. Validation accuracy: 0.746
# Epoch 4/10.. Train loss: 2.232.. Validation loss: 0.882.. Validation accuracy: 0.738
# Epoch 4/10.. Train loss: 1.911.. Validation loss: 0.954.. Validation accuracy: 0.728
# Epoch 4/10.. Train loss: 1.911.. Validation loss: 0.968.. Validation accuracy: 0.735
# Epoch 4/10.. Train loss: 1.979.. Validation loss: 0.940.. Validation accuracy: 0.739
# Epoch 4/10.. Train loss: 1.997.. Validation loss: 1.035.. Validation accuracy: 0.706
# Epoch 4/10.. Train loss: 1.984.. Validation loss: 1.014.. Validation accuracy: 0.707
# Epoch 4/10.. Train loss: 1.908.. Validation loss: 0.873.. Validation accuracy: 0.745
# Epoch 4/10.. Train loss: 1.931.. Validation loss: 0.866.. Validation accuracy: 0.750
# Epoch 4/10.. Train loss: 1.977.. Validation loss: 0.889.. Validation accuracy: 0.754
# Epoch 4/10.. Train loss: 1.956.. Validation loss: 0.873.. Validation accuracy: 0.758
# Epoch 4/10.. Train loss: 1.925.. Validation loss: 0.889.. Validation accuracy: 0.737
# Epoch 4/10.. Train loss: 1.933.. Validation loss: 0.923.. Validation accuracy: 0.745
# Epoch 4/10.. Train loss: 1.913.. Validation loss: 0.903.. Validation accuracy: 0.754
# Epoch 4/10.. Train loss: 2.018.. Validation loss: 0.883.. Validation accuracy: 0.761
# Epoch 4/10.. Train loss: 2.037.. Validation loss: 0.919.. Validation accuracy: 0.743
# Epoch 5/10.. Train loss: 1.739.. Validation loss: 1.034.. Validation accuracy: 0.737
# Epoch 5/10.. Train loss: 1.775.. Validation loss: 1.064.. Validation accuracy: 0.737
# Epoch 5/10.. Train loss: 2.311.. Validation loss: 1.049.. Validation accuracy: 0.724
# Epoch 5/10.. Train loss: 1.921.. Validation loss: 0.943.. Validation accuracy: 0.752
# Epoch 5/10.. Train loss: 1.886.. Validation loss: 0.890.. Validation accuracy: 0.759
# Epoch 5/10.. Train loss: 2.003.. Validation loss: 0.894.. Validation accuracy: 0.772
# Epoch 5/10.. Train loss: 1.793.. Validation loss: 0.854.. Validation accuracy: 0.766
# Epoch 5/10.. Train loss: 1.861.. Validation loss: 0.848.. Validation accuracy: 0.759
# Epoch 5/10.. Train loss: 2.035.. Validation loss: 0.896.. Validation accuracy: 0.758
# Epoch 5/10.. Train loss: 1.785.. Validation loss: 0.885.. Validation accuracy: 0.774
# Epoch 5/10.. Train loss: 1.966.. Validation loss: 0.900.. Validation accuracy: 0.765
# Epoch 5/10.. Train loss: 1.985.. Validation loss: 1.004.. Validation accuracy: 0.738
# Epoch 5/10.. Train loss: 1.983.. Validation loss: 1.004.. Validation accuracy: 0.740
# Epoch 5/10.. Train loss: 1.970.. Validation loss: 0.946.. Validation accuracy: 0.762
# Epoch 5/10.. Train loss: 1.893.. Validation loss: 0.961.. Validation accuracy: 0.748
# Epoch 5/10.. Train loss: 2.120.. Validation loss: 0.876.. Validation accuracy: 0.761
# Epoch 5/10.. Train loss: 1.893.. Validation loss: 0.856.. Validation accuracy: 0.779
# Epoch 5/10.. Train loss: 1.921.. Validation loss: 0.837.. Validation accuracy: 0.784
# Epoch 5/10.. Train loss: 1.879.. Validation loss: 0.784.. Validation accuracy: 0.818
# Epoch 5/10.. Train loss: 1.903.. Validation loss: 0.815.. Validation accuracy: 0.803
# Epoch 5/10.. Train loss: 2.000.. Validation loss: 0.855.. Validation accuracy: 0.767
# Epoch 6/10.. Train loss: 1.739.. Validation loss: 0.913.. Validation accuracy: 0.750
# Epoch 6/10.. Train loss: 1.879.. Validation loss: 0.862.. Validation accuracy: 0.766
# Epoch 6/10.. Train loss: 1.972.. Validation loss: 0.805.. Validation accuracy: 0.776
# Epoch 6/10.. Train loss: 2.108.. Validation loss: 0.761.. Validation accuracy: 0.800
# Epoch 6/10.. Train loss: 1.759.. Validation loss: 0.798.. Validation accuracy: 0.798
# Epoch 6/10.. Train loss: 1.814.. Validation loss: 0.860.. Validation accuracy: 0.786
# Epoch 6/10.. Train loss: 1.844.. Validation loss: 0.839.. Validation accuracy: 0.800
# Epoch 6/10.. Train loss: 1.722.. Validation loss: 0.815.. Validation accuracy: 0.807
# Epoch 6/10.. Train loss: 2.012.. Validation loss: 0.878.. Validation accuracy: 0.774
# Epoch 6/10.. Train loss: 1.906.. Validation loss: 0.912.. Validation accuracy: 0.770
# Epoch 6/10.. Train loss: 1.927.. Validation loss: 0.837.. Validation accuracy: 0.797
# Epoch 6/10.. Train loss: 1.825.. Validation loss: 0.849.. Validation accuracy: 0.780
# Epoch 6/10.. Train loss: 1.932.. Validation loss: 0.872.. Validation accuracy: 0.785
# Epoch 6/10.. Train loss: 1.747.. Validation loss: 0.889.. Validation accuracy: 0.789
# Epoch 6/10.. Train loss: 1.959.. Validation loss: 0.830.. Validation accuracy: 0.790
# Epoch 6/10.. Train loss: 1.818.. Validation loss: 0.787.. Validation accuracy: 0.790
# Epoch 6/10.. Train loss: 1.996.. Validation loss: 0.823.. Validation accuracy: 0.774
# Epoch 6/10.. Train loss: 1.745.. Validation loss: 0.814.. Validation accuracy: 0.782
# Epoch 6/10.. Train loss: 1.725.. Validation loss: 0.796.. Validation accuracy: 0.787
# Epoch 6/10.. Train loss: 1.563.. Validation loss: 0.827.. Validation accuracy: 0.782
# Epoch 7/10.. Train loss: 1.902.. Validation loss: 0.856.. Validation accuracy: 0.796
# Epoch 7/10.. Train loss: 1.781.. Validation loss: 0.909.. Validation accuracy: 0.775
# Epoch 7/10.. Train loss: 1.914.. Validation loss: 0.904.. Validation accuracy: 0.771
# Epoch 7/10.. Train loss: 1.758.. Validation loss: 0.852.. Validation accuracy: 0.778
# Epoch 7/10.. Train loss: 1.720.. Validation loss: 0.786.. Validation accuracy: 0.796
# Epoch 7/10.. Train loss: 1.507.. Validation loss: 0.797.. Validation accuracy: 0.787
# Epoch 7/10.. Train loss: 1.751.. Validation loss: 0.811.. Validation accuracy: 0.788
# Epoch 7/10.. Train loss: 1.862.. Validation loss: 0.800.. Validation accuracy: 0.787
# Epoch 7/10.. Train loss: 1.703.. Validation loss: 0.851.. Validation accuracy: 0.783
# Epoch 7/10.. Train loss: 1.654.. Validation loss: 0.850.. Validation accuracy: 0.790
# Epoch 7/10.. Train loss: 1.886.. Validation loss: 0.793.. Validation accuracy: 0.788
# Epoch 7/10.. Train loss: 1.965.. Validation loss: 0.757.. Validation accuracy: 0.792
# Epoch 7/10.. Train loss: 1.701.. Validation loss: 0.781.. Validation accuracy: 0.799
# Epoch 7/10.. Train loss: 1.894.. Validation loss: 0.760.. Validation accuracy: 0.799
# Epoch 7/10.. Train loss: 1.912.. Validation loss: 0.762.. Validation accuracy: 0.817
# Epoch 7/10.. Train loss: 1.793.. Validation loss: 0.757.. Validation accuracy: 0.808
# Epoch 7/10.. Train loss: 1.878.. Validation loss: 0.761.. Validation accuracy: 0.802
# Epoch 7/10.. Train loss: 1.836.. Validation loss: 0.736.. Validation accuracy: 0.809
# Epoch 7/10.. Train loss: 1.900.. Validation loss: 0.752.. Validation accuracy: 0.791
# Epoch 7/10.. Train loss: 1.898.. Validation loss: 0.768.. Validation accuracy: 0.802
# Epoch 7/10.. Train loss: 2.001.. Validation loss: 0.791.. Validation accuracy: 0.793
# Epoch 8/10.. Train loss: 1.881.. Validation loss: 0.800.. Validation accuracy: 0.787
# Epoch 8/10.. Train loss: 1.858.. Validation loss: 0.787.. Validation accuracy: 0.798
# Epoch 8/10.. Train loss: 1.774.. Validation loss: 0.772.. Validation accuracy: 0.803
# Epoch 8/10.. Train loss: 1.979.. Validation loss: 0.756.. Validation accuracy: 0.798
# Epoch 8/10.. Train loss: 1.777.. Validation loss: 0.720.. Validation accuracy: 0.820
# Epoch 8/10.. Train loss: 1.924.. Validation loss: 0.696.. Validation accuracy: 0.827
# Epoch 8/10.. Train loss: 1.707.. Validation loss: 0.680.. Validation accuracy: 0.828
# Epoch 8/10.. Train loss: 1.626.. Validation loss: 0.713.. Validation accuracy: 0.824
# Epoch 8/10.. Train loss: 1.578.. Validation loss: 0.733.. Validation accuracy: 0.823
# Epoch 8/10.. Train loss: 1.875.. Validation loss: 0.751.. Validation accuracy: 0.820
# Epoch 8/10.. Train loss: 1.942.. Validation loss: 0.707.. Validation accuracy: 0.820
# Epoch 8/10.. Train loss: 1.753.. Validation loss: 0.658.. Validation accuracy: 0.832
# Epoch 8/10.. Train loss: 1.879.. Validation loss: 0.741.. Validation accuracy: 0.819
# Epoch 8/10.. Train loss: 1.804.. Validation loss: 0.804.. Validation accuracy: 0.788
# Epoch 8/10.. Train loss: 1.898.. Validation loss: 0.862.. Validation accuracy: 0.784
# Epoch 8/10.. Train loss: 1.566.. Validation loss: 0.866.. Validation accuracy: 0.779
# Epoch 8/10.. Train loss: 1.750.. Validation loss: 0.791.. Validation accuracy: 0.796
# Epoch 8/10.. Train loss: 1.941.. Validation loss: 0.773.. Validation accuracy: 0.786
# Epoch 8/10.. Train loss: 1.873.. Validation loss: 0.774.. Validation accuracy: 0.798
# Epoch 8/10.. Train loss: 1.974.. Validation loss: 0.734.. Validation accuracy: 0.809
# Epoch 9/10.. Train loss: 1.634.. Validation loss: 0.750.. Validation accuracy: 0.799
# Epoch 9/10.. Train loss: 1.848.. Validation loss: 0.742.. Validation accuracy: 0.817
# Epoch 9/10.. Train loss: 1.714.. Validation loss: 0.779.. Validation accuracy: 0.808
# Epoch 9/10.. Train loss: 1.774.. Validation loss: 0.813.. Validation accuracy: 0.797
# Epoch 9/10.. Train loss: 1.654.. Validation loss: 0.768.. Validation accuracy: 0.804
# Epoch 9/10.. Train loss: 1.670.. Validation loss: 0.743.. Validation accuracy: 0.814
# Epoch 9/10.. Train loss: 1.847.. Validation loss: 0.734.. Validation accuracy: 0.816
# Epoch 9/10.. Train loss: 1.721.. Validation loss: 0.728.. Validation accuracy: 0.823
# Epoch 9/10.. Train loss: 1.913.. Validation loss: 0.725.. Validation accuracy: 0.822
# Epoch 9/10.. Train loss: 1.534.. Validation loss: 0.707.. Validation accuracy: 0.814
# Epoch 9/10.. Train loss: 1.913.. Validation loss: 0.702.. Validation accuracy: 0.815
# Epoch 9/10.. Train loss: 1.763.. Validation loss: 0.689.. Validation accuracy: 0.815
# Epoch 9/10.. Train loss: 1.682.. Validation loss: 0.710.. Validation accuracy: 0.814
# Epoch 9/10.. Train loss: 1.718.. Validation loss: 0.743.. Validation accuracy: 0.798
# Epoch 9/10.. Train loss: 1.814.. Validation loss: 0.828.. Validation accuracy: 0.787
# Epoch 9/10.. Train loss: 1.892.. Validation loss: 0.868.. Validation accuracy: 0.781
# Epoch 9/10.. Train loss: 1.941.. Validation loss: 0.784.. Validation accuracy: 0.791
# Epoch 9/10.. Train loss: 1.948.. Validation loss: 0.657.. Validation accuracy: 0.827
# Epoch 9/10.. Train loss: 1.785.. Validation loss: 0.666.. Validation accuracy: 0.833
# Epoch 9/10.. Train loss: 1.900.. Validation loss: 0.691.. Validation accuracy: 0.834
# Epoch 9/10.. Train loss: 1.767.. Validation loss: 0.762.. Validation accuracy: 0.814
# Epoch 10/10.. Train loss: 1.641.. Validation loss: 0.787.. Validation accuracy: 0.801
# Epoch 10/10.. Train loss: 1.573.. Validation loss: 0.776.. Validation accuracy: 0.810
# Epoch 10/10.. Train loss: 1.897.. Validation loss: 0.746.. Validation accuracy: 0.828
# Epoch 10/10.. Train loss: 1.663.. Validation loss: 0.742.. Validation accuracy: 0.820
# Epoch 10/10.. Train loss: 1.636.. Validation loss: 0.842.. Validation accuracy: 0.797
# Epoch 10/10.. Train loss: 1.804.. Validation loss: 0.875.. Validation accuracy: 0.795
# Epoch 10/10.. Train loss: 1.963.. Validation loss: 0.854.. Validation accuracy: 0.787
# Epoch 10/10.. Train loss: 1.768.. Validation loss: 0.823.. Validation accuracy: 0.795
# Epoch 10/10.. Train loss: 1.878.. Validation loss: 0.821.. Validation accuracy: 0.789
# Epoch 10/10.. Train loss: 1.767.. Validation loss: 0.762.. Validation accuracy: 0.793
# Epoch 10/10.. Train loss: 1.738.. Validation loss: 0.732.. Validation accuracy: 0.800
# Epoch 10/10.. Train loss: 1.847.. Validation loss: 0.772.. Validation accuracy: 0.793
# Epoch 10/10.. Train loss: 1.933.. Validation loss: 0.746.. Validation accuracy: 0.810
# Epoch 10/10.. Train loss: 1.868.. Validation loss: 0.722.. Validation accuracy: 0.810
# Epoch 10/10.. Train loss: 1.876.. Validation loss: 0.744.. Validation accuracy: 0.802
# Epoch 10/10.. Train loss: 1.897.. Validation loss: 0.720.. Validation accuracy: 0.819
# Epoch 10/10.. Train loss: 1.791.. Validation loss: 0.704.. Validation accuracy: 0.826
# Epoch 10/10.. Train loss: 1.755.. Validation loss: 0.761.. Validation accuracy: 0.814
# Epoch 10/10.. Train loss: 1.909.. Validation loss: 0.812.. Validation accuracy: 0.801
# Epoch 10/10.. Train loss: 1.970.. Validation loss: 0.755.. Validation accuracy: 0.816
# Epoch 10/10.. Train loss: 1.625.. Validation loss: 0.772.. Validation accuracy: 0.814

# %%
# print("Our model: \n\n", model, '\n')
# print("The state dict keys: \n\n", model.state_dict().keys())

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set

model.eval()
accuracy = 0
test_loss = 0

with torch.no_grad():
    for inputs, labels in testloader:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        #loss = criterion(logps, labels)
        #test_loss = test_loss + loss.item()

        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test accuracy: {accuracy/len(testloader):.3f}")
# Out:
# Test accuracy: 0.791

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_data.class_to_idx
checkpoint = {'arch': 'vgg13',
              'input_size': 25088,
              'mid_size': 3500,
              'output_size': 102,
              'dropout_prob': 0.2,
              'state_dict': model.state_dict(),
              'class_to_idx': model.class_to_idx}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def load_checkpoint(filepath, map_location):
    checkpoint = torch.load(filepath, map_location=map_location)

    model = models.vgg13(pretrained=True)

    # Freeze parameters
    for param in model.parameters():
        param.requires_grad = False

    model.class_to_idx = checkpoint['class_to_idx']

    classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(checkpoint['input_size'], checkpoint['mid_size'])),
                          ('dropout', nn.Dropout(checkpoint['dropout_prob'])),
                          ('relu', nn.ReLU()),
                          ('fc2', nn.Linear(checkpoint['mid_size'], checkpoint['output_size'])),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
    model.classifier = classifier
    model.load_state_dict(checkpoint['state_dict'])
    model.eval()
    
    return model

# %%
if torch.cuda.is_available():
    map_location=lambda storage, loc: storage.cuda()
else:
    map_location='cpu'

model = load_checkpoint('checkpoint.pth', map_location)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg13-c768596a.pth" to /root/.torch/models/vgg13-c768596a.pth
# 100%|██████████| 532194478/532194478 [00:05<00:00, 98329052.77it/s]

# %%
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU(inplace)
#     (17): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (20): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU(inplace)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU(inplace)
#     (24): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=3500, bias=True)
#     (dropout): Dropout(p=0.2)
#     (relu): ReLU()
#     (fc2): Linear(in_features=3500, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
    
    image = Image.open(image)
    image_transform = transforms.Compose([transforms.Resize(256),
                                          transforms.CenterCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],
                                                               [0.229, 0.224, 0.225])])
    
    return image_transform(image)

# %%
image_path = test_dir + '/19/image_06197.jpg'
Image.open(image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=749x500 at 0x7F090591FAC8>

# %%
image_processed = process_image(image_path)
image_processed.shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
imshow(image_processed)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # TODO: Implement the code to predict the class from an image file
    image_processed = process_image(image_path)
    image_processed.unsqueeze_(0)
    
    with torch.no_grad():
        output = model.forward(image_processed)
    
    ps = torch.exp(output)
    top_ps, top_class = ps.topk(topk)
    
    class_to_idx = {}
    for key, value in model.class_to_idx.items():
        class_to_idx[value] = key
        
    top_labels_np = top_class[0].numpy()
    
    top_labels = []
    for label in top_labels_np:
        top_labels.append(int(class_to_idx[label]))
        
    top_f = [cat_to_name[str(label)] for label in top_labels]
    
    return top_ps, top_labels, top_f

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
print(image_path)
predict(image_path, model, topk=5)
# Out:
# flowers/test/19/image_06197.jpg
# (tensor([[ 0.9889,  0.0092,  0.0007,  0.0006,  0.0003]]),
#  [19, 51, 76, 1, 98],
#  ['balloon flower',
#   'petunia',
#   'morning glory',
#   'pink primrose',
#   'mexican petunia'])

# %%
plt.figure(figsize = (5,7))
ax = plt.subplot(2,1,1)

flower = image_path.split('/')[2]
flower_name = cat_to_name[flower]

img = process_image(image_path)
plt.title(flower_name)
imshow(img, ax)

top_ps, top_class, top_flowers = predict(image_path, model) 
top_probs = top_ps[0].detach().numpy()

plt.subplot(2,1,2)
sns.barplot(x=top_probs, y=top_flowers, color=sns.color_palette()[0]);
plt.show()

# %%
image_path = test_dir + '/19/image_06196.jpg'
plt.figure(figsize = (5,7))
ax = plt.subplot(2,1,1)

flower = image_path.split('/')[2]
flower_name = cat_to_name[flower]

img = process_image(image_path)
plt.title(flower_name)
imshow(img, ax)

top_ps, top_class, top_flower = predict(image_path, model) 
top_probs = top_ps[0].detach().numpy()

plt.subplot(2,1,2)
sns.barplot(x=top_probs, y=top_flowers, color=sns.color_palette()[0]);
plt.show()

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
